# %% [markdown]
# <a href="https://colab.research.google.com/github/mark92233/FUNDAI-Lab1/blob/main/CS_FUNDAI_2026_Lab1_Ando.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Step 4: Add a Markdown Title Cell
# In the first cell, change the cell type to Text or Markdown, then enter:
#
# # Lab 1: Environment Onboarding
#
# ## Fundamentals of Artificial Intelligence
#
# **Name:** Ando, Mark John S
# **Course:** BSCSAI
# **Section:** 2A
# **Date:** August 18, 2026
# **GitHub URL:** https://github.com/mark92233/FUNDAI-Lab1.git
#
# ## Description
# This laboratory introduces the use of Google Colab and GitHub for AI laboratory activities. It also implements a simple intelligent agent.

# %%
import sys
import datetime

print("python version: ")
print(sys.version)

print("Today's date and time: ")
print(datetime.datetime.today())
# Out:
# python version:
# 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# Today's date and time:
# 2026-08-18 06:34:05.722435

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
folder_path = "/content/drive/My Drive/2026/FIRST-SEMESTER/AI-EL_FUNDIA/FUNDAI_Lab1"
os.makedirs(folder_path, exist_ok=True)

print("Folder ready: ", folder_path)
# Out:
# Folder ready:  /content/drive/My Drive/2026/FIRST-SEMESTER/AI-EL_FUNDIA/FUNDAI_Lab1

# %% [markdown]
# ## Simple intelligent Agent
#
# This simple agent recieves a room as a percept and produces an action.
#
# The agent follows a condition-action rule:
#
# -If the room is dirty, the agent cleans.
# -If the room is clean, the agent rests.
# -If the room condition is unkown, the agent inspects.

# %%
def simple_reflex_agent(room_condition):
  """
  A simple reflex agent that decides an action base on the room condition.
  """
  room_condition = room_condition.strip().lower()

  if room_condition == "dirty":
    return "CLEAN"
  elif room_condition == "clean":
    return "REST"
  else:
    return "INSPECT"

# %%
percepts = ["dirty", "clean", "dirty", "unkown"]

print("Simple Reflex Agent Test")
print("-" * 30)

for i, percept in enumerate(percepts, start=1):
  action = simple_reflex_agent(percept)
  print(f"Percept {i}: {percept:<8} -> Action: {action}")
# Out:
# Simple Reflex Agent Test
# ------------------------------
# Percept 1: dirty    -> Action: CLEAN
# Percept 2: clean    -> Action: REST
# Percept 3: dirty    -> Action: CLEAN
# Percept 4: unkown   -> Action: INSPECT

# %% [markdown]
# ## Performance Measure
#
# A simple performance measure gives a score when the agent chooses the correct action for the given percept.

# %%
score = 0
total = len(percepts)

for percept in percepts:
  action = simple_reflex_agent(percept)

  if(percept == "dirty" and action == "CLEAN"):
    score += 1
  elif(percept == "clean" and action == "REST"):
    score += 1
  elif(percept == "unkown" and action == "INSPECT"):
    score += 1

print(f"Agent score:  {score}/ {total}")
# Out:
# Agent score:  4/ 4

# %% [markdown]
# ## Guide Questions and Answers
#
# ### 1. What is an intelligent agent?
# **Answer: ** An intelligent is a system that percieves its environment through sensors and acts upon that environment through actuators.
#
# ### 2. What are the sensors and the actuators in simple agent example?
# **Answer: ** In this example the sensor input is the room condition percept.
# The actuator is the action such as CLEAN, REST, or INSPECT.
#
# ###3. Why is documentation important on AI laboratory work
# **Answer:**Documentation explainsthe purpose of the code, shows the result and helps the instructor evaluate the student's understanding.

# %% [markdown]
# ## Reflection
# ### Challenges Encountered
# - The ammount of text we need to type for documentation
# -The keyboard as I used laptop keyboard or mechanical as my default.
# -The run time
#
# ###What I learned
# -That agentic AI's markdown file serves as the instruction for the AI.
# -Agentic differs as it acts upon the given instruction.
